# %% [markdown]
# <a href="https://colab.research.google.com/github/soumilsaha12/FirstML/blob/main/Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load the input image -- 'chair.jpg'
# Convert it to grayscale
input_file = "/content/chair.jpeg"
img = cv2.imread(input_file, cv2.IMREAD_GRAYSCALE)

h, w = img.shape
print(f"height:{h}, width:{w}")

sobel_horizontal = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
sobel_vertical = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

laplacian = cv2.Laplacian(img, cv2.CV_64F)
canny = cv2.Canny(img, 50, 240)

cv2_imshow(img)
cv2_imshow(sobel_horizontal)
cv2_imshow(sobel_vertical)
cv2_imshow(laplacian)
cv2_imshow(canny)
cv2.waitKey()
# Out:
# height:408, width:612
# <PIL.Image.Image image mode=L size=612x408>
# <PIL.Image.Image image mode=L size=612x408>
# <PIL.Image.Image image mode=L size=612x408>
# <PIL.Image.Image image mode=L size=612x408>
# <PIL.Image.Image image mode=L size=612x408>
# -1

# %%
import sys
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Load input image -- 'box.png'
input_file = "/content/chair.jpeg"
img = cv2.imread(input_file)
cv2_imshow(img)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = np.float32(img_gray)
# Harris corner detector
img_harris = cv2.cornerHarris(img_gray, 7, 5, 0.04)
# Resultant image is dilated to mark the corners
img_harris = cv2.dilate(img_harris, None)
# Threshold the image
img[img_harris > 0.01 * img_harris.max()] = [0, 0, 0]
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>
# <PIL.Image.Image image mode=RGB size=612x408>
# -1

# %%
import sys
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
input_file = "/content/chair.jpeg"
img = cv2.imread(input_file)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
img_gray_histeq = cv2.equalizeHist(img_gray)
cv2_imshow( img_gray_histeq)
img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
img_histeq = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
cv2_imshow( img)
cv2_imshow( img_histeq)
# Out:
# <PIL.Image.Image image mode=L size=612x408>
# <PIL.Image.Image image mode=L size=612x408>
# <PIL.Image.Image image mode=RGB size=612x408>
# <PIL.Image.Image image mode=RGB size=612x408>
